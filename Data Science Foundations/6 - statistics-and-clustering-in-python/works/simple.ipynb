# %%
import numpy as np
data = [[1,2], [3,4], [5,6]]
data = np.array(data)
data[:,1]
# Out:
# array([2, 4, 6])

# %%
data = [[1,2], [3,4], [5,6]]
data = np.array(data)

# %%
[data[0][1], data[1][1], data[2][1]]
# Out:
# [2, 4, 6]

# %%
[data[0][1], data[1][1], data[2][1]]
# Out:
# [2, 4, 6]

# %%
data[:,1]
# Out:
# array([2, 4, 6])

# %%
data = [[1,2], [3,4], [5,6]]
data = np.array(data)

# %%
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
data.mean()
# Out:
# 3.5

# %%
np.mean(data,1)
# Out:
# array([1.5, 3.5, 5.5])

# %%
data.mean(0)
# Out:
# array([3., 4.])
