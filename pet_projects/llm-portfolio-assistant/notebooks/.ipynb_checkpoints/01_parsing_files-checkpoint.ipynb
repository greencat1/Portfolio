# %% [markdown]
# ### Imports

# %%
import os
import json
from pypdf import PdfReader
from tqdm import tqdm

# %% [markdown]
# ### Path

# %%
DATA_ROOT = "../../.."
OUTPUT_PATH = "../data/processed/parsed_data.json"

# %% [markdown]
# ### Collecting all files

# %%
def collect_files(root_dir):
    """
    Recursively walks through a directory
    and collects all file paths.
    """
    all_files = []
    
    for root, _, files in os.walk(root_dir):
    
        for file in files:
            full_path = os.path.join(root, file)
            all_files.append(full_path)
    
    return all_files


files = collect_files(DATA_ROOT)

print(f"Total files found: {len(files)}")
print(os.listdir(DATA_ROOT))
# Out:
# Total files found: 28050
# ['.git', 'Courses', 'pet_projects', 'README.md', 'scientific publications']

# %% [markdown]
# ### Detect File Type

# %%
def get_file_type(path):
    """
    Detect file type based on extension
    """
    if path.endswith(".md"):
        return "md"
    elif path.endswith(".ipynb"):
        return "ipynb"
    elif path.endswith(".py"):
        return "py"
    elif path.endswith(".pdf"):
        return "pdf"
    else:
        return "other"

# %% [markdown]
# ### Parse Markdown Files

# %%
def parse_md(path):
    """
    Reads markdown file as plain text
    """
    try:
        with open(path, "r", encoding="utf-8") as f:
            return f.read()
    except Exception as e:
        print(f"Error reading {path}: {e}")
        return ""

# %% [markdown]
# ### Parse Jupyter Notebooks

# %%
def parse_ipynb(path):
    """
    Parses a Jupyter notebook and returns structured cells
    
    IMPORTANT:
    - We do NOT merge markdown and code here
    - We preserve the original structure
    """
    try:
        with open(path, "r", encoding="utf-8") as f:
            notebook = json.load(f)
        
        cells = []
        
        for cell in notebook.get("cells", []):
            cell_type = cell.get("cell_type")
            source = "".join(cell.get("source", []))
            
            cells.append({
                "type": cell_type,
                "text": source
            })
        
        return cells
    
    except Exception as e:
        print(f"Error parsing ipynb {path}: {e}")
        return []

# %% [markdown]
# ### Parse Python Files

# %%
def parse_py(path):
    """
    Reads Python file as raw text
    
    IMPORTANT:
    No semantic analysis here — just extraction
    """
    try:
        with open(path, "r", encoding="utf-8") as f:
            return f.read()
    except Exception as e:
        print(f"Error reading {path}: {e}")
        return ""

# %% [markdown]
# ### Parse PDF Files

# %%
def parse_pdf(path):
    """
    Extracts text from PDF files
    """
    try:
        reader = PdfReader(path)
        text = ""
        
        for page in reader.pages:
            text += page.extract_text() or ""
        
        return text
    
    except Exception as e:
        print(f"Error parsing PDF {path}: {e}")
        return ""

# %% [markdown]
# ### Detect Project Name (Metadata)

# %%
def detect_project(path):
    """
    Detects project name based on file path
    
    Example:
    data/raw/churn/... → churn
    """
    parts = path.split(os.sep)
    
    if "churn" in parts:
        return "churn"
    elif "traffic" in parts:
        return "traffic_sign"
    elif 'Courses' in parts:
        return 'courses'
    elif 'scientific publications' in parts:
        return 'scientific_publications'
    else:
        return "unknown"

# %% [markdown]
# ### Main Parsing Pipeline

# %%
parsed_data = []

for path in tqdm(files):
    
    file_type = get_file_type(path)
    
    # skip irrelevant files
    if file_type == "other":
        continue
    
    project = detect_project(path)
    
    if file_type == "md":
        content = parse_md(path)
    
    elif file_type == "ipynb":
        content = parse_ipynb(path)
    
    elif file_type == "py":
        content = parse_py(path)
    
    elif file_type == "pdf":
        content = parse_pdf(path)
    
    else:
        continue
    
    parsed_data.append({
        "file": path,
        "project": project,
        "type": file_type,
        "content": content
    })
# Out:
#   4%|███▏                                                                       | 1190/28050 [00:00<00:09, 2954.56it/s]
# Error parsing PDF ../../..\Courses\Applied Data Science with Python Specialization\2 - Applied Plotting, Charting & Data Representation in Python\Applied Plotting, Charting & Data Representation in Python.pdf: [Errno 2] No such file or directory: '../../..\\Courses\\Applied Data Science with Python Specialization\\2 - Applied Plotting, Charting & Data Representation in Python\\Applied Plotting, Charting & Data Representation in Python.pdf'
# Error parsing ipynb ../../..\Courses\Applied Data Science with Python Specialization\2 - Applied Plotting, Charting & Data Representation in Python\2\.ipynb_checkpoints\assignment2-checkpoint.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Applied Data Science with Python Specialization\\2 - Applied Plotting, Charting & Data Representation in Python\\2\\.ipynb_checkpoints\\assignment2-checkpoint.ipynb'
# Error parsing ipynb ../../..\Courses\Applied Data Science with Python Specialization\2 - Applied Plotting, Charting & Data Representation in Python\3\.ipynb_checkpoints\assignment3-checkpoint.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Applied Data Science with Python Specialization\\2 - Applied Plotting, Charting & Data Representation in Python\\3\\.ipynb_checkpoints\\assignment3-checkpoint.ipynb'
# Error parsing ipynb ../../..\Courses\Applied Data Science with Python Specialization\2 - Applied Plotting, Charting & Data Representation in Python\4\.ipynb_checkpoints\assignment4-checkpoint.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Applied Data Science with Python Specialization\\2 - Applied Plotting, Charting & Data Representation in Python\\4\\.ipynb_checkpoints\\assignment4-checkpoint.ipynb'
# Error parsing ipynb ../../..\Courses\Data Science Foundations\8 - python-project-for-data-science\project\.ipynb_checkpoints\Revenue Data and Building a Dashboard-checkpoint.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Foundations\\8 - python-project-for-data-science\\project\\.ipynb_checkpoints\\Revenue Data and Building a Dashboard-checkpoint.ipynb'
# Error parsing PDF ../../..\Courses\Data Science Fundamentals with Python and SQL Specialization\Databases and SQL for Data Science with Python\Databases and SQL for Data Science with Python.pdf: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Fundamentals with Python and SQL Specialization\\Databases and SQL for Data Science with Python\\Databases and SQL for Data Science with Python.pdf'
# Error parsing ipynb ../../..\Courses\Data Science Fundamentals with Python and SQL Specialization\Python for Data Science, AI & Development\.ipynb_checkpoints\simple-checkpoint.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Fundamentals with Python and SQL Specialization\\Python for Data Science, AI & Development\\.ipynb_checkpoints\\simple-checkpoint.ipynb'
# Error parsing ipynb ../../..\Courses\Data Science Fundamentals with Python and SQL Specialization\Python Project for Data Science\project\Revenue Data and Building a Dashboard.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Fundamentals with Python and SQL Specialization\\Python Project for Data Science\\project\\Revenue Data and Building a Dashboard.ipynb'
# Error reading ../../..\Courses\Data Science Fundamentals with Python and SQL Specialization\Python Project for Data Science\project\Revenue Data and Building a Dashboard.md: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Fundamentals with Python and SQL Specialization\\Python Project for Data Science\\project\\Revenue Data and Building a Dashboard.md'
# Error parsing ipynb ../../..\Courses\Data Science Fundamentals with Python and SQL Specialization\Python Project for Data Science\project\.ipynb_checkpoints\Revenue Data and Building a Dashboard-checkpoint.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Fundamentals with Python and SQL Specialization\\Python Project for Data Science\\project\\.ipynb_checkpoints\\Revenue Data and Building a Dashboard-checkpoint.ipynb'
# Error parsing PDF ../../..\Courses\Data Science Fundamentals with Python and SQL Specialization\Statistics for Data Science with Python\Statistics for Data Science with Python.pdf: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Fundamentals with Python and SQL Specialization\\Statistics for Data Science with Python\\Statistics for Data Science with Python.pdf'
# Error parsing ipynb ../../..\Courses\Data Science Fundamentals with Python and SQL Specialization\Statistics for Data Science with Python\project\FinalProject_Boston Housing.ipynb: [Errno 2] No such file or directory: '../../..\\Courses\\Data Science Fundamentals with Python and SQL Specialization\\Statistics for Data Science with Python\\project\\FinalProject_Boston Housing.ipynb'
# 100%|██████████████████████████████████████████████████████████████████████████| 28050/28050 [00:22<00:00, 1242.85it/s]

# %%
len(parsed_data)
# Out:
# 300

# %%
parsed_data[0]
# Out:
# {'file': '../../..\\README.md',
#  'project': 'unknown',
#  'type': 'md',
#  'content': '# 📊 Data Science & Machine Learning Portfolio\n\nWelcome to my **Data Science & Machine Learning portfolio**.\n\nThis repository contains my coursework, applied projects, and independent pet projects, demonstrating my progression from data science fundamentals to advanced, real-world analytical and machine learning solutions.\n\nThe portfolio focuses on **practical problem-solving**, **clean analytical workflows**, and **reproducible Python-based data science**.\n\n---\n\n## 📂 Repository Structure\n\n```text\nPortfolio/  \n├── Courses/  \n│   ├── Applied Data Science with Python/  \n│   ├── More Applied Data Science with Python/  \n│   ├── Data Science Foundations/\n│   ├── Data Science Fundamentals with Python and SQL Specialization/\n│   ├── IBM Generative AI Engineering Professional Certificate/  \n│   └── Certificates/  \n│  \n├── Pet_Projects/ # Hands-on ML projects\n│   ├── customer-churn-prediction/     # Churn prediction service (FastAPI + Docker)\n│   ├── traffic-sign-detection/        # Road signs detection service (FastAPI + Docker)\n│   └── llm-portfolio-assistant/       # RAG assistant for portfolio (NEW!)\n│  \n├── scientific publications/\n│   ├── Traffic_Sign_Detection_SSD/\n│   ├── YOLOv7_Traffic_Sign_Detection/\n│  \n└── README.md\n```\n\n---\n\n## 🚀 Featured Projects\n\n### 🚦 Traffic Sign Detection (Production)\n\nReal-time traffic sign recognition system using **YOLO + ResNet cascade architecture (55 classes)**\n\n- **94.07% mAP50 / 91.71% Recall**\n- **+12.7% improvement vs baseline YOLO**\n- Real-time detection via **WebSocket + browser camera**\n- Two-stage architecture:\n  - YOLO → category detection\n  - 5× ResNet → fine classification\n\n🌐 **Live Demo:** https://greencat1.tech/  \n▶️ **Video Guide:** https://www.youtube.com/watch?v=XS1jED6fzpY  \n\n---\n\n### 📊 Customer Churn Prediction (Production)\n\nEnd-to-end ML system for predicting telecom churn.\n\n- **84.5% recall** (optimized for business impact)\n- REST API (**23 endpoints**) with authentication & rate limiting\n- Interactive **Streamlit dashboard**\n- Dockerized multi-container deployment\n\n🌐 **API Docs:** http://207.231.105.113:8000/docs  \n📊 **Dashboard:** http://207.231.105.113:8501  \n▶️ **Video Guide:** https://www.youtube.com/watch?v=zrF0L2pznhU  \n\n--- \n\n### 🤖 RAG Portfolio Assistant \n\nQuestion-answering system over my entire ML portfolio using Retrieval-Augmented Generation (RAG).\n\n- 8,361 semantic chunks from 291 files (.md, .ipynb, .py, .pdf)\n- FAISS vector search on CPU\n- Local LLM (tinyllama / phi3:mini via Ollama)\n- FastAPI backend + Streamlit chat interface\n- Fully local — no API calls to OpenAI/cloud\n\n🌐 Live Demo: http://207.231.105.113:8502/\n📚 Swagger API: http://207.231.105.113:8002/\n▶️ Video Guide: (coming soon)\n\n---\n\n## 🎓 Courses\n\nThe **Courses** folder contains coursework, assignments, and capstone projects completed as part of structured data science programs, including Python- and SQL-based analytics.\n\nThese materials demonstrate hands-on experience with real-world datasets, relational data sources, and end-to-end analytical workflows — from raw data extraction to insight generation, model development, and evaluation.\n\nThe projects typically follow a structured **data science workflow**, including:\n\n- Data collection and ingestion  \n- Data cleaning and preprocessing  \n- Exploratory data analysis (EDA)  \n- Feature engineering  \n- Model development and evaluation  \n- Result interpretation and visualization  \n\n### Topics & Competencies Covered\n\n- **Data analysis with Python** (Pandas, NumPy, data cleaning, feature engineering)  \n- **Relational data analysis with SQL** (SELECT queries, JOINs, aggregations, subqueries, basic window functions)  \n- **Exploratory data analysis (EDA) & visualization** (Matplotlib, Seaborn, insight-driven storytelling)  \n- **Machine learning** (supervised & unsupervised methods, model selection, validation, and evaluation metrics such as accur ...

# %% [markdown]
# ### Save to JSON

# %%
os.makedirs(os.path.dirname(OUTPUT_PATH), exist_ok=True)

with open(OUTPUT_PATH, "w", encoding="utf-8") as f:
    json.dump(parsed_data, f, ensure_ascii=False, indent=2)

print(f"Saved to {OUTPUT_PATH}")
# Out:
# Saved to ../data/processed/parsed_data.json

# %% [markdown]
# ### Summary
#
# - Implemented a pipeline to **collect and process files** from the portfolio directory
# - Supported multiple formats: `.md`, `.ipynb`, `.py`, `.pdf`
# - Extracted raw content while preserving structure (especially for notebooks)
# - Added basic metadata (project name, file type, path)
# - Saved all parsed data into a **structured JSON file**
#
# Result: unified raw dataset ready for semantic processing (next step in RAG pipeline)
